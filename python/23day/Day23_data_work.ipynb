# %% [markdown]
# ### 데이터산업의 기술등급별 데이터직무 인력 현황
#
# * 데이터 직무별 axe 생성
#     - x축: 시점
#     - y축: 업종(2개)
#
# * 하나의 figure에, 총8개 axe가 바둑판 형식으로 배치되는 형태 (4 col,2 rows)
# * title 표시

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
from matplotlib import font_manager, rc

current_font_list = matplotlib.rcParams['font.family']

font_path = "C:/Windows/Fonts/H2GTRE.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
# rc('font', family=font)
matplotlib.rcParams['font.family'] = [font]+current_font_list
print(matplotlib.rcParams['font.family'])
# Out:
# ['HYGothic-Extra', 'sans-serif']

# %%
pd_data = pd.read_csv('데이터산업의_기술등급별_데이터직무_인력_현황_20230303160342.csv', encoding='cp949')
pd_data = pd_data.drop('기술등급별(1)',axis=1)
pd_data.columns = ['데이터직무별','시점','데이터 처리 및 관리 솔루션 개발·공급업','데이터 구축 및 컨설팅 서비스업']
pd_data
# Out:
#         데이터직무별    시점  데이터 처리 및 관리 솔루션 개발·공급업  데이터 구축 및 컨설팅 서비스업
# 0     데이터 아키텍트  2018                     806               4330
# 1     데이터 아키텍트  2019                    1202               4355
# 2     데이터 아키텍트  2020                    1588               4915
# 3     데이터 아키텍트  2021                    2061               6044
# 4      데이터 개발자  2018                    4579              16302
# 5      데이터 개발자  2019                    4799              17092
# 6      데이터 개발자  2020                    5683              18173
# 7      데이터 개발자  2021                    7891              21858
# 8     데이터 엔지니어  2018                    1616               7528
# 9     데이터 엔지니어  2019                    1862               8035
# 10    데이터 엔지니어  2020                    2421               8780
# 11    데이터 엔지니어  2021                    3276               9866
# 12     데이터 분석가  2018                     892               2457
# 13     데이터 분석가  2019                    1039               2794
# 14     데이터 분석가  2020                    1292               3011
# 15     데이터 분석가  2021                    1519               3828
# 16  데이터베이스 관리자  2018                     842               4617
# 17  데이터베이스 관리자  2019                    1023               4644
# 18  데이터베이스 관리자  2020                    1409               6098
# 19  데이터베이스 관리자  2021                    1769               7736
# 20     데이터 과학자  2018                     218                581
# 21     데이터 과학자  2019                     288                784
# 22     데이터 과학자  2020                     540               1149
# 23     데이터 과학자  2021                     762               1443
# 24    데이터 컨설턴트  2018                    1736               2904
# 25    데이터 컨설턴트  2019                    2076               3001
# 26    데이터 컨설턴트  2020                    2265               3672
# 27    데이터 컨설턴트  2021                    2556               4856
# 28     데이터 기획자  2018                     852               1478
# 29     데이터 기획자  2019                    1177               2274
# 30     데이터 기획자  2020                    2075               2845
# 31     데이터 기획자  2021                    2289               3101

# %%
fig, axe = plt.subplots(2,4, figsize=(24,10))
fig.suptitle('데이터산업의 기술등급별 데이터직무 인력 현황')

for i in range(8):
    sub_data = pd_data.iloc[4*i:4*(i+1)]
    x = sub_data['시점']
    y1 = sub_data['데이터 처리 및 관리 솔루션 개발·공급업']
    y2 = sub_data['데이터 구축 및 컨설팅 서비스업']
    title = sub_data['데이터직무별']
    axe[i//4,i%4].plot(x,y1, color = 'red', label='데이터 처리 및 관리 솔루션 개발·공급업', linestyle=':',linewidth=2)
    axe[i//4,i%4].plot(x,y2, color = 'blue',label='데이터 구축 및 컨설팅 서비스업',linestyle=':',linewidth=2)
    axe[i//4,i%4].set_title(title[i*4])
    axe[i//4,i%4].set_xlabel('year',fontsize=12)
    axe[i//4,i%4].set_ylabel('number of people',fontsize=12)
    axe[i//4,i%4].legend()
    axe[i//4,i%4].set_xticks(x)
    axe[i//4,i%4]
#     axe[i//4,i%4].set_xlim(left=x.min(), right=x.max())
    axe[i//4,i%4].set_yticks(np.linspace(0,25000,6))
    axe[i//4,i%4].tick_params(axis='both', direction='in')
fig.savefig('데이터 직무 인력 현황.png')
