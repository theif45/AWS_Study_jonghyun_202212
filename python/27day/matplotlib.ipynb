# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
import matplotlib.tri as mtri
from mpl_toolkits import mplot3d
from matplotlib import font_manager, rc

current_font_list = matplotlib.rcParams['font.family']

font_path = "C:/Windows/Fonts/H2GTRE.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
matplotlib.rcParams['font.family'] = [font]+current_font_list
print(matplotlib.rcParams['font.family'])

fig, axe = plt.subplots()
# axe.plot(np.linspace(0,1000,100),np.sin(np.linspace(0,180,100)))
axe.plot(np.sin(np.linspace(-1.0,1.0,10)))
fig.set_facecolor('blue')
axe.set_facecolor('red')
ax1 = fig.add_axes([0.2,0.5,0.2,0.3])
ax1.plot([1,2,3,4,5])
# Out:
# ['HYGothic-Extra', 'sans-serif']

# %%
fig1 = plt.figure(layout='tight')
ax1 = fig1.add_subplot(3,2,1)
ax2 = fig1.add_subplot(3,2,2)
ax3 = fig1.add_subplot(3,1,2)
ax4 = fig1.add_subplot(3,1,3)

# %%
df1 = pd.read_csv('이륜차신고현황_시도별_20230309170634.csv', encoding='cp949', header=[0,1])
df1.drop(('시도명(1)','시도명(1)'),axis=1,inplace=True)
df1
# df1[('계','경형')]
# col_name = ['시도명','시점','시군구','경형(계)','소형(계)','중형(계)','대형(계)','경형(관용)','소형(관용)','중형(관용)','대형(관용)','경형(자가용)','소형(자가용)','중형(자가용)','대형(자가용)']
# pd_data = pd_data.iloc[1:,:].reset_index(drop=True)
# pd_data.columns = col_name
# pd_data
# Out:
#          시점 시군구(1)    계                     관용              자가용               \
#          시점 시군구(1)   경형    소형     중형    대형  경형  소형  중형  대형   경형    소형     중형
# 0   2023.01    금정구  350  2072   5178   575   5   4  68   2  345  2068   5110
# 1   2023.01    기장군  311  1473   3475   627   2   8  58   0  309  1465   3417
# 2   2023.01     남구  451  2408   6964   941   3  10  18   0  448  2398   6946
# 3   2023.01     동구  185   963   3009   321   2  22  32   1  183   941   2977
# 4   2023.01    동래구  404  2133   5584   855   1   1  71   1  403  2132   5513
# 5   2023.01   부산진구  633  3922  10094  1397  10  21  86   1  623  3901  10008
# 6   2023.01     북구  414  2075   5532   720   1   4  45   0  413  2071   5487
# 7   2023.01    사상구  576  2276   5989   603  26  38  96   1  550  2238   5893
# 8   2023.01    사하구  528  2888   8168   969   6   2  72   0  522  2886   8096
# 9   2023.01     서구  207  1486   4033   342   1   6   2   0  206  1480   4031
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111, projection='3d')

# 원통
theta = np.linspace(0, 2 * np.pi, 100)
x = np.sin(theta)
y = np.cos(theta)
z = np.zeros_like(theta)
ax.plot(x, y, z, color='black')
z = np.ones_like(theta)
ax.plot(x, y, z, color='black')

# 구
u, v = np.mgrid[0:np.pi:20j, 0:2*np.pi:20j]
x = np.sin(u) * np.cos(v)
y = np.sin(u) * np.sin(v)
z = np.cos(u)
ax.plot_wireframe(x, y, z, color='gray', alpha=0.5)

# 정육면체
x = np.array([0, 1, 1, 0, 0, 1, 1, 0])
y = np.array([0, 0, 1, 1, 0, 0, 1, 1])
z = np.array([0, 0, 0, 0, 1, 1, 1, 1])
ax.plot(x, y, z, color='black')

# 축 범위를 설정합니다.
ax.set_xlim(-1.5, 1.5)
ax.set_ylim(-1.5, 1.5)
ax.set_zlim(-1.5, 1.5)

# 축 레이블을 설정합니다.
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

plt.show()

# %%
fig = plt.figure(figsize=(6.4*3,4.8*3),layout='constrained')
a = fig.add_subplot(2,2,1)
b = fig.add_subplot(2,2,2)
c = fig.add_subplot(2,2,3)
d = fig.add_subplot(2,2,4)

sns.barplot(x = pd_data['시군구'],y = pd_data['경형(계)'].astype(np.float64), ax=a)
sns.barplot(x = pd_data['시군구'],y = pd_data['소형(계)'].astype(np.float64), ax=b)
sns.barplot(x = pd_data['시군구'],y = pd_data['중형(계)'].astype(np.float64), ax=c)
sns.barplot(x = pd_data['시군구'],y = pd_data['대형(계)'].astype(np.float64), ax=d)
a.set_xticklabels(labels=pd_data['시군구'], fontsize=10, rotation=45)
b.set_xticklabels(labels=pd_data['시군구'], fontsize=10, rotation=45)
c.set_xticklabels(labels=pd_data['시군구'], fontsize=10, rotation=45)
d.set_xticklabels(labels=pd_data['시군구'], fontsize=10, rotation=45)
a.set_yticks(np.linspace(0,12000,7))
b.set_yticks(np.linspace(0,12000,7))
c.set_yticks(np.linspace(0,12000,7))
d.set_yticks(np.linspace(0,12000,7))

e = fig.add_axes([0.1,0.8,0.1,0.1])
f = fig.add_subplot(6,6,4)
g = fig.add_subplot(6,6,19)
h = fig.add_subplot(6,6,22)

sns.barplot(x = pd_data['시군구'],y = pd_data['경형(관용)'].astype(np.float64), ax=e)
sns.barplot(x = pd_data['시군구'],y = pd_data['소형(관용)'].astype(np.float64), ax=f)
sns.barplot(x = pd_data['시군구'],y = pd_data['중형(관용)'].astype(np.float64), ax=g)
sns.barplot(x = pd_data['시군구'],y = pd_data['대형(관용)'].astype(np.float64), ax=h)
e.set_xticklabels(labels='', fontsize=10, rotation=45)
f.set_xticklabels(labels='', fontsize=10, rotation=45)
g.set_xticklabels(labels='', fontsize=10, rotation=45)
h.set_xticklabels(labels='', fontsize=10, rotation=45)
e.set_yticklabels(labels='')
f.set_yticklabels(labels='')
g.set_yticklabels(labels='')
h.set_yticklabels(labels='')
# Out:
# [Text(0, 0.0, ''),
#  Text(0, 10.0, ''),
#  Text(0, 20.0, ''),
#  Text(0, 30.0, ''),
#  Text(0, 40.0, '')]

# %%
fig = plt.figure(figsize=(6.4*3,4.8*3))
a = fig.add_subplot(2,2,1)
b = fig.add_subplot(2,2,2)
c = fig.add_subplot(2,2,3)
d = fig.add_subplot(2,2,4)

sns.barplot(x = pd_data['시군구'],y = pd_data['경형(계)'].astype(np.float64), ax=a)
sns.barplot(x = pd_data['시군구'],y = pd_data['소형(계)'].astype(np.float64), ax=b)
sns.barplot(x = pd_data['시군구'],y = pd_data['중형(계)'].astype(np.float64), ax=c)
sns.barplot(x = pd_data['시군구'],y = pd_data['대형(계)'].astype(np.float64), ax=d)
a.set_xticklabels(labels=pd_data['시군구'], fontsize=10, rotation=45)
b.set_xticklabels(labels=pd_data['시군구'], fontsize=10, rotation=45)
c.set_xticklabels(labels=pd_data['시군구'], fontsize=10, rotation=45)
d.set_xticklabels(labels=pd_data['시군구'], fontsize=10, rotation=45)
a.set_yticks(np.linspace(0,12000,7))
b.set_yticks(np.linspace(0,12000,7))
c.set_yticks(np.linspace(0,12000,7))
d.set_yticks(np.linspace(0,12000,7))

# %%
fig = plt.figure(figsize=(6.4*3,4.8*3))
a = fig.add_subplot(2,2,1)
b = fig.add_subplot(2,2,2)
c = fig.add_subplot(2,2,3)
d = fig.add_subplot(2,2,4)

sns.barplot(x = pd_data['시군구'],y = pd_data['경형(관용)'].astype(np.float64), ax=a)
sns.barplot(x = pd_data['시군구'],y = pd_data['소형(관용)'].astype(np.float64), ax=b)
sns.barplot(x = pd_data['시군구'],y = pd_data['중형(관용)'].astype(np.float64), ax=c)
sns.barplot(x = pd_data['시군구'],y = pd_data['대형(관용)'].astype(np.float64), ax=d)
a.set_xticklabels(labels=pd_data['시군구'], fontsize=10, rotation=45)
b.set_xticklabels(labels=pd_data['시군구'], fontsize=10, rotation=45)
c.set_xticklabels(labels=pd_data['시군구'], fontsize=10, rotation=45)
d.set_xticklabels(labels=pd_data['시군구'], fontsize=10, rotation=45)
a.set_yticks(np.linspace(0,100,6))
b.set_yticks(np.linspace(0,100,6))
c.set_yticks(np.linspace(0,100,6))
d.set_yticks(np.linspace(0,100,6))

# %%
fig = plt.figure(figsize=(6.4*3,4.8*3))
a = fig.add_subplot(2,2,1)
b = fig.add_subplot(2,2,2)
c = fig.add_subplot(2,2,3)
d = fig.add_subplot(2,2,4)

sns.barplot(x = pd_data['시군구'],y = pd_data['경형(자가용)'].astype(np.float64), ax=a)
sns.barplot(x = pd_data['시군구'],y = pd_data['소형(자가용)'].astype(np.float64), ax=b)
sns.barplot(x = pd_data['시군구'],y = pd_data['중형(자가용)'].astype(np.float64), ax=c)
sns.barplot(x = pd_data['시군구'],y = pd_data['대형(자가용)'].astype(np.float64), ax=d)
a.set_xticklabels(labels=pd_data['시군구'], fontsize=10, rotation=45)
b.set_xticklabels(labels=pd_data['시군구'], fontsize=10, rotation=45)
c.set_xticklabels(labels=pd_data['시군구'], fontsize=10, rotation=45)
d.set_xticklabels(labels=pd_data['시군구'], fontsize=10, rotation=45)
a.set_yticks(np.linspace(0,12000,7))
b.set_yticks(np.linspace(0,12000,7))
c.set_yticks(np.linspace(0,12000,7))
d.set_yticks(np.linspace(0,12000,7))
